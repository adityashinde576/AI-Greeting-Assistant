# %%
name = input("Enter your name: ")
interest = input("Enter your area of AI interest (e.g., NLP, CV, Robotics): ")
print(f"Hello {name}! Great to know you're interested in {interest}.")
print("Python will help you master it!")
# Out:
# Enter your name:  Aditya
# Enter your area of AI interest (e.g., NLP, CV, Robotics):  NLP
# Hello Aditya! Great to know you're interested in NLP.
# Python will help you master it!
